# %%
def multiply(a, b):
    return a*b

# %%
multiply(3,5)

# %%
multiply(7,7)

# %%
multiply(6,7)

# %%
def square(x):
    return multiply(x, x)

# %%
square(2)
# Out:
# 4

# %%
square(3)
# Out:
# 9

# %%
square(4)
# Out:
# 16
