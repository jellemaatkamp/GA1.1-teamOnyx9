# %%
def subtract(a,b):
    return a-b

# %%
subtract([3,2,1],[1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 subtract([3,2,1],[1,2,3])
#
# Cell In[4], line 2, in subtract(a, b)
#       1 def subtract(a,b):
# ----> 2     return a-b
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
subtract(8,1)
# Out:
# 7

# %%
subtract(99,6)
# Out:
# 93

# %%
def distance_from_zero(x):
    return subtract(x, 0)

# %%
distance_from_zero(8)
# Out:
# 8
