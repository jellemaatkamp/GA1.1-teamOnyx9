# %%
def add(a, b):
    return a + b

# %%
add(20, 40)

# %%
add(2, 3)

# %%
add(4, 6)

# %% [markdown]
# ## New Function

# %%
def sum_list(values):
  counter = 0
  for i in values:
    counter = add(counter, i)
  return counter

# %%
sum_list([1, 2, 3, 4, 5])
